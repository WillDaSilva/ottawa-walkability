# %%
import geopandas as gpd

# %%
data = gpd.read_file('data.gpkg')

# %% [markdown]
# ### Schema
#
# | Column | Type | Description |
# | --- | --- | --- |
# | `id` | `float64` | Unique identifier for the 200m square geometry |
# | `ZONE_MAIN` | `object` (string) | The main zoning code for the 200m square |
# | `Walktime_SM` | `float64` | The average walk time to the nearest supermarket in minutes |
# | `Walktime_Cafe` | `float64` | The average walk time to the nearest cafe in minutes |
# | `Walktime_Rest` | `float64` | The average walk time to the nearest restaurant in minutes |
# | `Walktime_ISCED_1` | `float64` | The average walk time to the nearest ISCED 1 (primary) school in minutes |
# | `Walktime_ISCED_2` | `float64` | The average walk time to the nearest ISCED 2 (lower secondary) school in minutes |
# | `Walktime_ISCED_3` | `float64` | The average walk time to the nearest ISCED 3 (upper secondary) school in minutes |
# | `Walktime_Transit` | `float64` | The average walk time to the nearest rapid/frequent transit stop in minutes |
# | `Walktime_Park` | `float64` | The average walk time to the nearest park in minutes |
# | `Walktime_Library2` | `float64` | The average walk time to the nearest library in minutes |
# | `Average_Amentiy_Walktime` | `float64` | The average walk time to the nearest amenity of each type in minutes |
# | `geometry` | `geometry` | The 200m square geometry |

# %%
data
# Out:
#              id ZONE_MAIN  Walktime_SM  Walktime_Cafe  Walktime_Rest  \
# 0      189809.0        RM    36.963008      52.567498       5.634365
# 1      190692.0        RM    40.456829      56.061320       9.128186
# 2      191133.0        RM    43.012755      58.617246      11.684112
# 3      191575.0        RM    44.575942      60.180432      13.247299
# 4      192016.0        RM    46.685999      62.290490      15.357356
# ...         ...       ...          ...            ...            ...
# 17838  108451.0        R1    18.270445      16.338432      11.389773
# 17839  108452.0        R1    17.811064      15.879052      13.536256
# 17840  149675.0        RR   118.161431     112.172280      81.968836
# 17841  202491.0        R3     8.186874      10.568896       9.431371
# 17842  202932.0        R3    10.584224      10.599190      10.913829
#
#        Walktime_ISCED_1  Walktime_ISCED_2  Walktime_ISCED_3  Walktime_Transit  \
# ...
